# %%
#!pip install selenium
#!pip install pyautogui

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
import pyautogui

# %% [markdown]
# //*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr[16]/td
# //*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr[14]/td
#
# //*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr[16]/td

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium import webdriver
import time
import openpyxl
import pandas as pd
import pyautogui


driver1 = webdriver.Chrome("C:\chromedriver.exe")

#  창크기 최대화
driver1.maximize_window()

# 홈페이지 접속
driver1.get("https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc")
time.sleep(5)

# 좌표조회

# No.1 수업계획서 조회 버튼 좌표

print('Close Position:',pyautogui.position())
# No.1 조회 버튼 Position: Point(x=949, y=352)
# No.2 조회 버튼 Position: Point(x=952, y=367)
# No.3 조회 버튼 Position: Point(x=946, y=406)
# No.4 조회 버튼 Position: Point(x=949, y=427)
# No.5 조회 버튼 Position: Point(x=947, y=460)

# No. 맨 마지막 칸 조회 버튼 Position: Point(x=960, y=723)
# inner scroll 다운버튼 Position: Point(x=1880, y=737)

# for i in range(2, 16, 1):
    
#     xn = 957
#     yn = 352*(i-2)

#     #  창크기 최대화
#     driver1.maximize_window()

#     pyautogui.click(x=xn, y=yn, clicks= 2, button= 'left')
#     time.sleep(2)

#     driver1.switch_to.window(driver1.window_handles[0])

#     time.sleep(2)
#     print(f'No.{i-1}')

#     time.sleep(2)
#     driver1.switch_to.window(driver1.window_handles[1])
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_95464\961429889.py:15: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1 = webdriver.Chrome("C:\chromedriver.exe")
# Close Position: Point(x=948, y=720)

# %% [markdown]
# > ### 20230228_한성대_크롤링_수정_v2
# >
# > ####    < 해결해야 될 문제 >
# > - 17개 이상  데이터 뽑기
# > - 2006년 ~ 2023년 1학기까지 데이터 뽑기

# %%
# # 수업계획서 조회
# for j in range(2, 16, 1):
#     x_plot = 950
#     y_plot = 352+(30*(j-2))
#     print(x_plot, y_plot)

# No.1 조회 버튼 Position: Point(x=949, y=352)
# No.2 조회 버튼 Position: Point(x=952, y=367)
# No.3 조회 버튼 Position: Point(x=946, y=406)
# No.4 조회 버튼 Position: Point(x=949, y=427)

# No. 맨 마지막 칸 조회 버튼 Position: Point(x=960, y=723)

# 950 352
# 950 382
# 950 412
# 950 442
# 950 472
# 950 502
# 950 532
# 950 562
# 950 592
# 950 622
# 950 652
# 950 682
# 950 712
# 950 742
# Out:
# 950 352
# 950 382
# 950 412
# 950 442
# 950 472
# 950 502
# 950 532
# 950 562
# 950 592
# 950 622
# 950 652
# 950 682
# 950 712
# 950 742

# %%
# 20230228_수정_v2

# 15이상 안뽑히던 데이터 출력하기
# 2006년도 부터 2023까지 뽑기


from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium import webdriver
import time
import openpyxl
import pandas as pd
import pyautogui


driver = webdriver.Chrome("C:\chromedriver.exe")
#  창크기 최대화
driver.maximize_window()

# 홈페이지 접속
driver.get("https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc")
time.sleep(10)

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["학년","교과목명", "전공","교수","학점", "강의시간","개요","강의목표"])

major_txt = driver.find_element(By.XPATH,'//*[@id="jungong"]').text
major_list = major_txt.splitlines()
major_list = major_list[1:]
major_list_n = int(len(major_list))

check_list = [('이전 data2', '이전 data6')]

# 전공 조회
for i in range(0, major_list_n):

    print('//////////////////////////////////////////////////////////////////////////')

    # 수업계획서 조회
    for j in range(2, 1000, 1):
        print(f'{major_list[i]}/ No. {j-1}')

        # 수업계획서 크롤링
            
        # 문제 가 없는 index 15 이하까지는 원래 코드를 따름
        # //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[16]/td[13]/div

        if j < 16:
            # 수업 계획서 버튼 조회
            time.sleep(2)
            pyautogui.click(x=960, y=355+((j-2) * 30), clicks= 2, button='left')
            
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
            # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                    # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            # 전공
            try:
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])

            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            finally:
                if check_list[j-2] == check_list[j-1]:
                    break
            # 창변환    
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(2)

        else:
            # 스크롤 내림
            time.sleep(2)
            pyautogui.click(x=1880, y=737, clicks= 1, button='left')
            # 표 마지막 조회버튼을 누름
            pyautogui.click(x=960, y=723, clicks= 2, button='left')
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                data4 = ''
                print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            # 전공
            try:
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트    
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])

            # check_list 업데이트
            try:
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(1.5)
                print('<---------------------------------------------------------- \n')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(1.5)
                print('----------------------------------------------------------> \n')
            finally:
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(2)
                if check_list[j-2] == check_list[j-1]:
                    break


    driver.find_element(By.XPATH, '//*[@id="jungong"]').click()
    driver.find_element(By.XPATH, '//*[@id="jungong"]').send_keys(Keys.ARROW_DOWN)

                

wb.save("한성대.xlsx")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_89640\3472103964.py:21: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:\chromedriver.exe")
# //////////////////////////////////////////////////////////////////////////
#              [P011] 영미문학문화트랙/ No. 1
# 4학년
# Business English
# 투랄리자
# 3학점_전공선택
# 상상관503 월8M~9M / 탐구관307 수8M~9M
# The course is divided into five parts: socializing and being globally minded by showing cultural sensitivity; carrying out business telephone conversations; having a professional discussion in a business meeting; negotiating in business; writing a professional business letter. Students learn the necessary business expressions, listen to sample dialogs, then practice with a group or a partner.
# To enable students to carry out business related tasks as mentioned above and give them more confidence in using professional English at work.
#              [P011] 영미문학문화트랙
# ...

# %%
# 20230228_수정_v3

# 15이상 안뽑히던 데이터 출력하기 > 그냥 다 마우스 이동(좌표값)으로 구현
# 2006년도 부터 2023까지 뽑기


from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium import webdriver
import time
import openpyxl
import pandas as pd
import pyautogui


driver = webdriver.Chrome("C:\chromedriver.exe")
#  창크기 최대화
driver.maximize_window()

# 홈페이지 접속
driver.get("https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc")
time.sleep(5)

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["학년","교과목명", "전공","교수","학점", "강의시간","개요","강의목표"])

major_txt = driver.find_element(By.XPATH,'//*[@id="jungong"]').text
major_list = major_txt.splitlines()
major_list = major_list[1:]
major_list_n = int(len(major_list))


check_list = [('이전 data2', '이전 data6')]

# 전공 조회
for i in range(0, major_list_n):



    print('//////////////////////////////////////////////////////////////////////////')

    # 수업계획서 조회
    for j in range(1, 1000):
        print(f'{major_list[i]}/ No. {j-1}')

        # 수업계획서 크롤링

        if j == 1:

            # 수업 계획서 버튼 조회
            # No.1 조회 버튼 Position: Point(x=949, y=352)
            time.sleep(3)

            pyautogui.click(x = 949, y= 352, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')



        elif j == 2:

            # 수업 계획서 버튼 조회
            # No.2 조회 버튼 Position: Point(x=952, y=367)
            
            time.sleep(3)

            pyautogui.click(x = 949, y= 367, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 3:

            # 수업 계획서 버튼 조회
            # No.3 조회 버튼 Position: Point(x=946, y=406)

            time.sleep(3)

            pyautogui.click(x = 949, y= 406, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 4:

            # 수업 계획서 버튼 조회
            # No.4 조회 버튼 Position: Point(x=949, y=427)

            time.sleep(3)
            pyautogui.move(949, 427)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 5:

            # 수업 계획서 버튼 조회
            # No.5 조회 버튼 Position: Point(x=948, y=459)

            pyautogui.click(x = 949, y= 459, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 6:

            # 수업 계획서 버튼 조회
            # No.6 조회 버튼 Position: Pointx=950, y=486)

            pyautogui.click(x = 949, y= 486, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 7:

            # 수업 계획서 버튼 조회
            # No.7 조회 버튼 Position: Point(x=948, y=512)

            pyautogui.click(x = 949, y= 512, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 8:

            # 수업 계획서 버튼 조회
            # No.8 조회 버튼 Position: Point(x=948, y=537)

            pyautogui.click(x = 949, y= 537, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 9:

            # 수업 계획서 버튼 조회
            # No.9 조회 버튼 Position: Point(x=951, y=563)

            pyautogui.click(x = 951, y= 563, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 10:

            # 수업 계획서 버튼 조회
            # No.10 조회 버튼 Position: Point(x=948, y=590)

            pyautogui.click(x = 948, y= 590, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 11:

            # 수업 계획서 버튼 조회
            # No.11 조회 버튼 Position: Point(x=949, y=615)

            pyautogui.click(x = 949, y= 615, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')

        elif j == 12:

            # 수업 계획서 버튼 조회
            # No.12 조회 버튼 Position: Point(x=949, y=644)

            pyautogui.click(x = 949, y= 644, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 13:

            # 수업 계획서 버튼 조회
            # No.13 조회 버튼 Position: Point(x=948, y=668)

            pyautogui.click(x = 949, y= 668, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 14:

            # 수업 계획서 버튼 조회
            # No.14 조회 버튼 Position: Point(x=948, y=694)

            time.sleep(3)
            pyautogui.move(948, 694)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 15:

            # 수업 계획서 버튼 조회
            # No.15 조회 버튼 Position: Point(x=948, y=718)

            pyautogui.click(x = 948, y= 718, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        else:
            # 스크롤 내림
            time.sleep(1.5)
            pyautogui.click(x=1880, y=737, clicks= 1, button='left')
            # 표 마지막 조회버튼을 누름
            time.sleep(0.5)
            pyautogui.click(x=948, y=723, clicks= 2, button='left')
            time.sleep(0.5)
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                data4 = ''
                print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            # 전공
            try:
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트    
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)

        # check_list 업데이트
        try:
            check_list.append((data2, data6))
            print(f'현 check_list: {check_list[j-2]}')
            print('<---------------------------------------------------------- \n')
        except:
            check_list.append(('data2', 'data6'))
            print(f'현 check_list: {check_list[j-2]}')
            print('----------------------------------------------------------> \n')
        finally:
            if check_list[j-2] == check_list[j-1]:
                break
                

    driver.find_element(By.XPATH, '//*[@id="jungong"]').send_keys(Keys.ARROW_DOWN) 
          
                

wb.save("한성대.xlsx")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_100408\3885751944.py:21: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:\chromedriver.exe")
# //////////////////////////////////////////////////////////////////////////
#              [P011] 영미문학문화트랙/ No. 0
# 4학년
# Business English
# 투랄리자
# 3학점_전공선택
# 상상관503 월8M~9M / 탐구관307 수8M~9M
# The course is divided into five parts: socializing and being globally minded by showing cultural sensitivity; carrying out business telephone conversations; having a professional discussion in a business meeting; negotiating in business; writing a professional business letter. Students learn the necessary business expressions, listen to sample dialogs, then practice with a group or a partner.
# To enable students to carry out business related tasks as mentioned above and give them more confidence in using professional English at work.
#              [P011] 영미문학문화트랙
# ...

# %%
# 20230302_수정_v4_연습
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium import webdriver
import time
import openpyxl
import pandas as pd
import pyautogui


driver = webdriver.Chrome("C:\chromedriver.exe")
#  창크기 최대화
driver.maximize_window()

# 홈페이지 접속
driver.get("https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc")

time.sleep(3)
pyautogui.moveTo(949, 352)
time.sleep(0.5)
pyautogui.click()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_105944\3014694259.py:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:\chromedriver.exe")

# %%
# 20230302_수정_v4

# 15이상 안뽑히던 데이터 출력하기 > 그냥 다 마우스 이동(좌표값)으로 구현
# >>>마우스가 이동을 안함 개빡침;;;

# 2006년도 부터 2023까지 뽑기


from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium import webdriver
import time
import openpyxl
import pandas as pd
import pyautogui


driver = webdriver.Chrome("C:\chromedriver.exe")
#  창크기 최대화
driver.maximize_window()

# 홈페이지 접속
driver.get("https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc")
time.sleep(5)

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["학년","교과목명", "전공","교수","학점", "강의시간","개요","강의목표"])

major_txt = driver.find_element(By.XPATH,'//*[@id="jungong"]').text
major_list = major_txt.splitlines()
major_list = major_list[1:]
major_list_n = int(len(major_list))


check_list = [('이전 data2', '이전 data6')]

# 전공 조회
for i in range(0, major_list_n):



    print('//////////////////////////////////////////////////////////////////////////')

    # 수업계획서 조회
    for j in range(1, 1000):
        print(f'{major_list[i]}/ No. {j-1}')

        # 수업계획서 크롤링

        if j == 1:

            # 수업 계획서 버튼 조회
            # No.1 조회 버튼 Position: Point(x=949, y=352)
            time.sleep(3)
            pyautogui.moveTo(949, 352)
            time.sleep(0.5)
            pyautogui.click()
            
            
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')



        elif j == 2:

            # 수업 계획서 버튼 조회
            # No.2 조회 버튼 Position: Point(x=952, y=367)

            time.sleep(3)
            pyautogui.moveTo(952, 367)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 3:

            # 수업 계획서 버튼 조회
            # No.3 조회 버튼 Position: Point(x=946, y=406)

            time.sleep(3)
            pyautogui.moveTo(946, 406)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 4:

            # 수업 계획서 버튼 조회
            # No.4 조회 버튼 Position: Point(x=949, y=427)

            time.sleep(3)

            time.sleep(3)
            pyautogui.moveTo(949, 427)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 5:

            # 수업 계획서 버튼 조회
            # No.5 조회 버튼 Position: Point(x=948, y=459)

            time.sleep(3)
            pyautogui.moveTo(948, 459)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 6:

            # 수업 계획서 버튼 조회
            # No.6 조회 버튼 Position: Pointx=950, y=486)

            time.sleep(3)
            pyautogui.moveTo(950, 486)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 7:

            # 수업 계획서 버튼 조회
            # No.7 조회 버튼 Position: Point(x=948, y=512)

            time.sleep(3)
            pyautogui.moveTo(948, 512)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 8:

            # 수업 계획서 버튼 조회
            # No.8 조회 버튼 Position: Point(x=948, y=537)

            time.sleep(3)
            pyautogui.moveTo(948, 537)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 9:

            # 수업 계획서 버튼 조회
            # No.9 조회 버튼 Position: Point(x=951, y=563)

            time.sleep(3)
            pyautogui.moveTo(951, 563)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 10:

            # 수업 계획서 버튼 조회
            # No.10 조회 버튼 Position: Point(x=948, y=590)

            time.sleep(3)
            pyautogui.moveTo(948, 590)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 11:

            # 수업 계획서 버튼 조회
            # No.11 조회 버튼 Position: Point(x=949, y=615)

            time.sleep(3)
            pyautogui.moveTo(949, 615)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')

        elif j == 12:

            # 수업 계획서 버튼 조회
            # No.12 조회 버튼 Position: Point(x=949, y=644)

            time.sleep(3)
            pyautogui.moveTo(949, 644)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 13:

            # 수업 계획서 버튼 조회
            # No.13 조회 버튼 Position: Point(x=948, y=668)

            time.sleep(3)
            pyautogui.moveTo(948, 668)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 14:

            # 수업 계획서 버튼 조회
            # No.14 조회 버튼 Position: Point(x=948, y=694)

            time.sleep(3)
            pyautogui.moveTo(948, 694)
            time.sleep(0.5)
            pyautogui.click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        elif j == 15:

            # 수업 계획서 버튼 조회
            # No.15 조회 버튼 Position: Point(x=948, y=718)

            time.sleep(3)
            pyautogui.moveTo(948, 718)
            time.sleep(0.5)
            pyautogui.click()
                
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                    
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                    data4 = ''
                    print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            try:
                # 전공
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            
            # 창변환
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            
            # check_list 업데이트
            try: 
                check_list.append((data2, data6))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')
            except:
                check_list.append(('data2', 'data6'))
                print(f'현 check_list: {check_list[j-2]}')
                print('----------------------------------------------------------')


        else:
            # 스크롤 내림
            time.sleep(1.5)
            pyautogui.moveTo(1880, 737)
            time.sleep(0.5)
            pyautogui.click()
            
            # 표 마지막 조회버튼을 누름
            time.sleep(3)
            pyautogui.moveTo(948, 723)
            time.sleep(0.5)
            pyautogui.click()

                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                data4 = ''
                print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                    
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            # 전공
            try:
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)

            # excel 업데이트    
            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])
            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)

        # check_list 업데이트
        try:
            check_list.append((data2, data6))
            print(f'현 check_list: {check_list[j-2]}')
            print('<---------------------------------------------------------- \n')
        except:
            check_list.append(('data2', 'data6'))
            print(f'현 check_list: {check_list[j-2]}')
            print('----------------------------------------------------------> \n')
        finally:
            if check_list[j-2] == check_list[j-1]:
                break
                

    driver.find_element(By.XPATH, '//*[@id="jungong"]').send_keys(Keys.ARROW_DOWN) 
          
                

wb.save("한성대.xlsx")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_105944\4065095728.py:23: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:\chromedriver.exe")
# //////////////////////////////////////////////////////////////////////////
#              [P011] 영미문학문화트랙/ No. 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 68
#      63 pyautogui.click()
#      67 # 창변환
# ---> 68 driver.switch_to.window(driver.window_handles[1])
#      69 time.sleep(1.5)
#      71 try:
#      72     # 학년
#
# IndexError: list index out of range

# %%
# 승태님이 보내주신 코드 툴 기반 크롤링_v1 


from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium import webdriver
import time
import openpyxl
import pandas as pd
import pyautogui


driver = webdriver.Chrome("C:\chromedriver.exe")
#  창크기 최대화
driver.maximize_window()

# 홈페이지 접속
driver.get("https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc")
time.sleep(10)

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["학년","교과목명", "전공","교수","학점", "강의시간","개요","강의목표"])

# 전공 list
major_txt = driver.find_element(By.XPATH,'//*[@id="jungong"]').text
major_list = major_txt.splitlines()
major_list = major_list[1:]
major_list_n = int(len(major_list))

# 년도별 학기 list
hakgi_txt = driver.find_element(By.XPATH,'//*[@id="yearhakgi"]').text
hakgi_list = hakgi_txt.splitlines()
hakgi_list = hakgi_list[1:]
hakgi_list_n = int(len(hakgi_list))
hakgi_list_n



# 년도별 학기 조회
# 2023 1학기 ~ 2010 1학기까지
for s in range(53):
    print('*****************************************************************************')
    print(f'<<<<<<<<<<<<<<< {hakgi_list[s]} >>>>>>>>>>>>>>>>>')
    print('*****************************************************************************')
    
    # 전공 조회
    for i in range(0, major_list_n):
        print('/////////////////////////////////////////////////////////////////////////////////')
        print(f'<<< page {i}, 전공명: {major_list[i]} >>>')
        print('/////////////////////////////////////////////////////////////////////////////////')

        # 수업계획서 조회
        for j in range(2, 1000, 1):

            print(f'{major_list[i]}/ No. {j-1}')
            try:
                index_num =driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr['+str(j)+']/td').text
            except:
                break

            try:
                # 수업 계획서 버튼 조회
                driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr['+str(j)+']/td[13]/div').click()
                
                # 창변환
                driver.switch_to.window(driver.window_handles[1])
                time.sleep(1.5)
                
                try:
                    # 학년
                    data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                    print(data1)
                    time.sleep(0.5)
                except:
                    data1 = ''
                    print(data1)

                try:    
                    # 교과목명
                    data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                    print(data2)
                    time.sleep(0.5)
                except:
                    data2 = ''
                    print(data2)

                try:
                    # 교수
                    data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                    print(data4)
                    time.sleep(0.5)
                except:
                    data4 = ''
                    print(data4)
                
                try:
                    # 학점
                    data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                    print(data5)
                    time.sleep(0.5)
                except:
                    data5 = ''
                    print(data5)

                try:
                    # 강의시간
                    data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                    print(data6)
                    time.sleep(0.5)
                except:
                    data6 = ''
                    print(data6)

                try:
                    # 개요
                    data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                    print(data7)
                    time.sleep(0.5)
                except:
                    data7 = ''
                    print(data7)
                
                try:
                    # 강의목표
                    data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                    print(data8)
                    time.sleep(0.5)
                except:
                    data8 = ''
                    print(data8)

                # 전공
                try:
                    data3 = major_list[i]
                    print(data3)
                except:
                    data3 = ''
                    print(data3)


                print('----------------------------------------------------------')
                sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])

                driver.switch_to.window(driver.window_handles[0])
                time.sleep(1.5)
            

            except:
                pass

                
        # driver.find_element(By.XPATH, '//*[@id="jungong"]').click()
        driver.find_element(By.XPATH, '//*[@id="jungong"]').send_keys(Keys.ARROW_DOWN)

    
    driver.find_element(By.XPATH, '//*[@id="yearhakgi"]').send_keys(Keys.ARROW_DOWN)    

wb.save("한성대.xlsx")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_18380\3566591900.py:18: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:\chromedriver.exe")
# **************************************************
# <<<<<<<<<<<<<<<              2023년 1학기 >>>>>>>>>>>>>>>>>
# **************************************************
# -------------------------------------------------------------------------------
# <<< page 0, 전공명:              [P011] 영미문학문화트랙 >>>
# -------------------------------------------------------------------------------
#              [P011] 영미문학문화트랙/ No. 1
# 4학년
# Business English
# 투랄리자
# 3학점_전공선택
# 상상관503 월8M~9M / 탐구관307 수8M~9M
# ...

# %%
# 승태님이 보내주신 코드 툴 기반 크롤링_v1_실험용 > [성공] 안되면 집갈때 이거 돌리면 됨


from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium import webdriver
import time
import openpyxl
import pandas as pd
import pyautogui


driver = webdriver.Chrome("C:\chromedriver.exe")
#  창크기 최대화
driver.maximize_window()

# 홈페이지 접속
driver.get("https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc")
time.sleep(10)

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["학년","교과목명", "전공","교수","학점", "강의시간","개요","강의목표"])

# 전공 list
major_txt = driver.find_element(By.XPATH,'//*[@id="jungong"]').text
major_list = major_txt.splitlines()
major_list = major_list[1:]
major_list_n = int(len(major_list))

# 년도별 학기 list
hakgi_txt = driver.find_element(By.XPATH,'//*[@id="yearhakgi"]').text
hakgi_list = hakgi_txt.splitlines()
hakgi_list = hakgi_list[1:]
hakgi_list_n = int(len(hakgi_list))
hakgi_list_n

print(f' 현 학기: {hakgi_list[0]}')
driver.find_element(By.XPATH, '//*[@id="yearhakgi"]').send_keys(Keys.ARROW_DOWN)

for i in range(0, major_list_n):
    print('-------------------------------------------------------------------------------')
    print(f'<<< page {i}, 전공명: {major_list[i]} >>>')
    print('-------------------------------------------------------------------------------')

    # 수업계획서 조회
    for j in range(2, 1000, 1):

        print(f'{major_list[i]}/ No. {j-1}')
        try:
            index_num =driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr['+str(j)+']/td').text
        except:
            break

        try:
            # 수업 계획서 버튼 조회
            driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr['+str(j)+']/td[13]/div').click()
                
            # 창변환
            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1.5)
                
            try:
                # 학년
                data1 = driver.find_element(By.XPATH,'//*[@id="daesang"]').text
                print(data1)
                time.sleep(0.5)
            except:
                data1 = ''
                print(data1)

            try:    
                # 교과목명
                data2 = driver.find_element(By.XPATH,'//*[@id="kwamok"]').text
                print(data2)
                time.sleep(0.5)
            except:
                data2 = ''
                print(data2)

            try:
                # 교수
                data4 = driver.find_element(By.XPATH,'//*[@id="pname"]').text
                print(data4)
                time.sleep(0.5)
            except:
                data4 = ''
                print(data4)
                
            try:
                # 학점
                data5 = driver.find_element(By.XPATH,'//*[@id="hakjum"]').text
                print(data5)
                time.sleep(0.5)
            except:
                data5 = ''
                print(data5)

            try:
                # 강의시간
                data6 = driver.find_element(By.XPATH, '//*[@id="timeclassroom"]').text
                print(data6)
                time.sleep(0.5)
            except:
                data6 = ''
                print(data6)

            try:
                # 개요
                data7 = driver.find_element(By.XPATH, '//*[@id="gaeyo"]').text
                print(data7)
                time.sleep(0.5)
            except:
                data7 = ''
                print(data7)
                
            try:
                # 강의목표
                data8 = driver.find_element(By.XPATH, '//*[@id="mokpyo"]').text
                print(data8)
                time.sleep(0.5)
            except:
                data8 = ''
                print(data8)

            # 전공
            try:
                data3 = major_list[i]
                print(data3)
            except:
                data3 = ''
                print(data3)


            print('----------------------------------------------------------')
            sheet.append([data1,data2,data3,data4,data5,data6,data7,data8])

            driver.switch_to.window(driver.window_handles[0])
            time.sleep(1.5)
            

        except:
            pass

                
    # driver.find_element(By.XPATH, '//*[@id="jungong"]').click()
    driver.find_element(By.XPATH, '//*[@id="jungong"]').send_keys(Keys.ARROW_DOWN)

wb.save("한성대.xlsx")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_104384\4062558302.py:18: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:\chromedriver.exe")
#  현 학기:              2023년 1학기
# -------------------------------------------------------------------------------
# <<< page 0, 전공명:              [P011] 영미문학문화트랙 >>>
# -------------------------------------------------------------------------------
#              [P011] 영미문학문화트랙/ No. 1
# 4학년
# Business English
# 투랄리자
# 3학점_전공선택
# 상상관503 월8M~9M / 탐구관307 수8M~9M
# The course is divided into five parts: socializing and being globally minded by showing cultural sensitivity; carrying out business telephone conversations; having a professional discussion in a business meeting; negotiating in business; writing a professional business letter. Students learn the necessary business expressions, listen to sample dialogs, then practice with a group or a partner.
# ...

# %% [markdown]
# > ### 시간표 및 수업계획서조회 사이트 접속

# %%
# #path, url 주소
# path = "chromedriver.exe"
# url1 = "https://info.hansung.ac.kr/"

# driver = webdriver.Chrome(path)
# driver.get(url1)
# time.sleep(1.5)

# #  창크기 최대화
# driver.maximize_window()
# time.sleep(1.5)

# # 로그인 하기
# driver.find_element(By.NAME,'id').send_keys(1692092)
# driver.find_element(By.NAME,'passwd').send_keys('.rla55869053')
# driver.find_element(By.XPATH,'//*[@id="loginBtn"]').click()
# time.sleep(1.5)

#교무 > 수업계획서 조회 이동은 실패고 링크를 알아내버림;;;;;
path = "chromedriver.exe"
url_ = 'https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc' 
driver = webdriver.Chrome(path)
driver.get(url_)
time.sleep(1.5)

#  창크기 최대화
driver.maximize_window()
time.sleep(1.5)

major_txt = driver.find_element(By.XPATH,'//*[@id="jungong"]').text
major_list = major_txt.splitlines()
major_list = major_list[1:]
# len(major_list)
# major_list

t_list = []

# 전공변경(클릭으로 대체)
driver.find_element(By.XPATH, '//*[@id="jungong"]').click()
driver.find_element(By.XPATH, '//*[@id="jungong"]').send_keys(Keys.ARROW_DOWN)

# 내부 수업 계획서 데이터 추출 
for i in range(2, 19):
    
    t2 = driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr['+str(i)+']/td').text

    driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr['+str(i)+']/td[13]/div/span').click()
    driver.switch_to.window(driver.window_handles[1])
    time.sleep(1.5)
    
    t = driver.find_element(By.XPATH,'//*[@id="inner"]/table[1]/tbody[1]/tr[5]/td[1]').text
    print(t, t2)
    t_list.append(t)
    
    
    driver.switch_to.window(driver.window_handles[0])
    time.sleep(0.5)
    driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[12]/div[4]').click()
   

# # index1 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[13]/div/span').click()
# # index2 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[3]/td[13]/div/span').click()

# #index 6
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[7]/td[13]/div/span').click()

# #index 9
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[10]/td[13]/div/span').click()

# # index11 수업계획서 클릭        
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[12]/td[13]/div/span').click()


# 14 >> //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[12]/td[13]/div/span
# 15 >> //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[13]/td[13]/div/span
# 16 >> //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[14]/td[13]/div/span
# 17  >> //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[15]/td[13]/div/span
# # index18 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[16]/td[13]/div/span').click()


# driver.switch_to.window(driver.window_handles[1])

# t = driver.find_element(By.XPATH,'//*[@id="inner"]/table[1]/tbody[1]/tr[5]/td[1]').text
# time.sleep(1.5)
# driver.switch_to.window(driver.window_handles[0])
# t
# driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[1]').text
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[13]/div/span').click()
# time.sleep(1.5)


#driver.find_element(By.XPATH,'//*[@id="inner"]/table[1]/tbody[1]/tr[3]/td[2]').text
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_87456\4173743558.py:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# 성명투랄리자 1
# 성명투랄리자 3
# 성명박종언 5
# 성명문귀선 7
# 성명투랄리자 9
# 성명정혜란 11
# 성명강상구 13
# 성명박지영 14
# 성명이종은 15
# 성명강상구 16
# 성명강상구 17
# 성명강상구 18
# 성명강상구 19
# 성명김덕자 20
# 성명김덕자 21
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[9], line 40
#      36 for i in range(2, 19):
#      38     t2 = driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr['+str(i)+']/td').text
# ---> 40     driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr['+str(i)+']/td[13]/div/span').click()
#      41     driver.switch_to.window(driver.window_handles[1])
#      42     time.sleep(1.5)
#
# ...

# %%
t_list
len(t_list)
# Out:
# 15

# %% [markdown]
# //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[13]/div
# //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[3]/td[13]/div
#
#
# //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[13]/td[13]/div
#
# //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[16]/td[13]/div

# %% [markdown]
# > ### 전공 콤보박스 관련 Code

# %%
#//*[@id="jungong"]/option[108] >>> for in range(1,109): 2023-1


path = "chromedriver.exe"
url_ = 'https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc' 
driver = webdriver.Chrome(path)
driver.get(url_)
time.sleep(1.5)

#  창크기 최대화
driver.maximize_window()
time.sleep(1.5)


major_txt = driver.find_element(By.XPATH,'//*[@id="jungong"]').text
major_list = major_txt.splitlines()
major_index_num = len(major_list)  # >> for i in range(1, major_index_num)

t_list = []

# 전공변경(클릭으로 대체)
for i in range(2):

    if i < 1:
        for j in range(2, 19):
    
            try:
                # t2: index
                t2 = driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr['+str(j)+']/td').text

                driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr['+str(j)+']/td[13]/div/span').click()
                driver.switch_to.window(driver.window_handles[1])
                time.sleep(1.5)
                
                t = driver.find_element(By.XPATH,'//*[@id="inner"]/table[1]/tbody[1]/tr[5]/td[1]').text
                #print(t, t2)
                t_list.append(t)
                
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(0.5)
                
            finally:
                print(t, t2)
        
    else:
        driver.find_element(By.XPATH, '//*[@id="jungong"]').click()
        driver.find_element(By.XPATH, '//*[@id="jungong"]').send_keys(Keys.ARROW_DOWN)

        for j in range(2, 19):
    
            try:
                t2 = driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr['+str(j)+']/td').text

                driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr['+str(j)+']/td[13]/div/span').click()
                driver.switch_to.window(driver.window_handles[1])
                time.sleep(1.5)
                
                t = driver.find_element(By.XPATH,'//*[@id="inner"]/table[1]/tbody[1]/tr[5]/td[1]').text
                print(t, t2)
                t_list.append(t)
                
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(0.5)
                
            finally:
                print(t, t2)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_24828\174541712.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# 성명투랄리자 1
# 성명투랄리자 2
# 성명투랄리자 3
# 성명투랄리자 4
# 성명투랄리자 5
# 성명투랄리자 6
# 성명정혜란 7
# 성명이병은 8
# 성명이병은 9
# 성명이병은 10
# 성명이병은 11
# 성명정혜란 12
# 성명강상구 13
# 성명강상구 14
# 성명김혜윤 15
# 성명김혜윤 16
# 성명김혜윤 16
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[5], line 28
#      25 for j in range(2, 19):
#      27     try:
# ---> 28         t2 = driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[3]/div[2]/table/tbody/tr['+str(j)+']/td').text
#      30         driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr['+str(j)+']/td[13]/div/span').click()
#      31         driver.switch_to.window(driver.window_handles[1])
#
# ...

# %% [markdown]
# > ### 수업계획서 조회 관련 Code
# > 수업계획서 조회 URL 패턴)
# > https://info.hansung.ac.kr/fuz/professor/lecturePlan/suupplan_main_view.jsp?code=20231110632M0200217
# > https://info.hansung.ac.kr/fuz/professor/lecturePlan/suupplan_main_view.jsp?code=20231110105R010019A
#
# > 해당 과목코드 당 강의가 1개인 경우,
#
# #13
# //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[11]/td[13]/div
# #14
# //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[12]/td[13]/div
# #15
#
# #16
# //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[14]/td[13]/div
# #17
# //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[15]/td[13]/div
# #18
# //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[16]/td[13]/div

# %%
# # index1 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[13]/div/span').click()
# # index2 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[3]/td[13]/div/span').click()
# # index3 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[4]/td[13]/div/span').click()

# %% [markdown]
# > ### 접속한 수강계획서 내 크롤링 Code

# %%
# # 과목명
# //*[@id="inner"]/table[1]/tbody[1]/tr[2]/td[1]
# # 수강대상
# //*[@id="inner"]/table[1]/tbody[1]/tr[3]/td[2]
# # 소속
# //*[@id="inner"]/table[1]/tbody[1]/tr[5]/td[2]
# # 교과목개요
# //*[@id="inner"]/table[1]/tbody[3]/tr[10]/td
# # 수업목표
# //*[@id="inner"]/table[1]/tbody[3]/tr[12]/td



#driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[1]/div/div/a').text

# time.sleep(1.5)
# pyautogui.click(x=73, y=270, clicks= 2, button='left')  # 해당 좌표값(닫기 버튼) 클릭
# time.sleep(10)

# %% [markdown]
# > ### 현 진행상황 반영 전반적(전체) Code

# %%
# #path, url 주소
# path = "chromedriver.exe"
# url1 = "https://info.hansung.ac.kr/"

# driver = webdriver.Chrome(path)
# driver.get(url1)
# time.sleep(1.5)

# #  창크기 최대화
# driver.maximize_window()
# time.sleep(1.5)

# # 로그인 하기
# driver.find_element(By.NAME,'id').send_keys(1692092)
# driver.find_element(By.NAME,'passwd').send_keys('.rla55869053')
# driver.find_element(By.XPATH,'//*[@id="loginBtn"]').click()
# time.sleep(1.5)

#교무 > 수업계획서 조회 이동은 실패고 링크를 알아내버림;;;;;
path = "chromedriver.exe"
url2 = 'https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc' 
driver = webdriver.Chrome(path)
driver.get(url2)
time.sleep(1.5)

#  창크기 최대화
driver.maximize_window()
time.sleep(1.5)

major_txt = driver.find_element(By.XPATH,'//*[@id="jungong"]').text
major_list = major_txt.splitlines()
major_list = major_list[1:]
len(major_list)
#major_list

#//*[@id="jungong"]/option[108] >>> for in range(1,109): 2023-1

# # index1 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[13]/div/span').click()
# # index2 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[3]/td[13]/div/span').click()
# # index3 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[4]/td[13]/div/span').click()










# # 과목명
# //*[@id="inner"]/table[1]/tbody[1]/tr[2]/td[1]
# # 수강대상
# //*[@id="inner"]/table[1]/tbody[1]/tr[3]/td[2]
# # 소속
# //*[@id="inner"]/table[1]/tbody[1]/tr[5]/td[2]
# # 교과목개요
# //*[@id="inner"]/table[1]/tbody[3]/tr[10]/td
# # 수업목표
# //*[@id="inner"]/table[1]/tbody[3]/tr[12]/td



#driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[1]/div/div/a').text

# time.sleep(1.5)
# pyautogui.click(x=73, y=270, clicks= 2, button='left')  # 해당 좌표값(닫기 버튼) 클릭
# time.sleep(10)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_30504\2756031854.py:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# 108

# %%
# #path, url 주소
# path = "chromedriver.exe"
# url1 = "https://info.hansung.ac.kr/"

# driver = webdriver.Chrome(path)
# driver.get(url1)
# time.sleep(1.5)

# #  창크기 최대화
# driver.maximize_window()
# time.sleep(1.5)

# # 로그인 하기
# driver.find_element(By.NAME,'id').send_keys(1692092)
# driver.find_element(By.NAME,'passwd').send_keys('.rla55869053')
# driver.find_element(By.XPATH,'//*[@id="loginBtn"]').click()
# time.sleep(1.5)

#교무 > 수업계획서 조회 이동은 실패고 링크를 알아내버림;;;;;
path = "chromedriver.exe"
url_ = 'https://info.hansung.ac.kr/jsp_21/student/kyomu/siganpyo_aui.jsp?viewMode=oc' 
driver = webdriver.Chrome(path)
driver.get(url_)
time.sleep(1.5)

t_list = []

#  창크기 최대화
driver.maximize_window()
time.sleep(1.5)

driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[13]/div/span').click() # 조회
time.sleep(2)

driver.switch_to.window(driver.window_handles[1])


t = driver.find_element(By.XPATH,'//*[@id="inner"]/table[1]/tbody[1]/tr[5]/td[1]').text #교수명
t_list.append(t)


driver.switch_to.window(driver.window_handles[0])
driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[12]/div[4]').click()



# # inner_scroll_class_name = col-12
# itemlist = driver.find_element(By.CLASS_NAME, "col-12")
# driver.execute_script("arguments[0].scrollBy(0, 1000)", itemlist)



# for i in range(2,19):
    
#     driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr['+str(i)+']/td[13]/div/span').click() # 조회
#     time.sleep(2)

#     driver.switch_to.window(driver.window_handles[1])


#     t = driver.find_element(By.XPATH,'//*[@id="inner"]/table[1]/tbody[1]/tr[5]/td[1]').text #교수명
#     t_list.append(t)


#     driver.switch_to.window(driver.window_handles[0])
#     driver.execute_script("window.scrollTo(0, -5)")
   



# # index1 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[13]/div/span').click()
# # index2 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[3]/td[13]/div/span').click()

# #index 6
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[7]/td[13]/div/span').click()

# #index 9
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[10]/td[13]/div/span').click()

# # index11 수업계획서 클릭        
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[12]/td[13]/div/span').click()


# 14 >> //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[12]/td[13]/div/span
# 15 >> //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[13]/td[13]/div/span
# 16 >> //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[14]/td[13]/div/span
# 17  >> //*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[15]/td[13]/div/span
# # index18 수업계획서 클릭
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[16]/td[13]/div/span').click()



# driver.switch_to.window(driver.window_handles[1])

# t = driver.find_element(By.XPATH,'//*[@id="inner"]/table[1]/tbody[1]/tr[5]/td[1]').text
# time.sleep(1.5)
# driver.switch_to.window(driver.window_handles[0])
# t
# driver.find_element(By.XPATH,'//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[1]').text
# driver.find_element(By.XPATH, '//*[@id="grid_wrap"]/div/div[2]/div/div[1]/div[2]/table/tbody/tr[2]/td[13]/div/span').click()
# time.sleep(1.5)


#driver.find_element(By.XPATH,'//*[@id="inner"]/table[1]/tbody[1]/tr[3]/td[2]').text
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_61888\1042620394.py:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
len(t_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 len(t_list)
#
# NameError: name 't_list' is not defined
