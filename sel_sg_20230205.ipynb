# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
import time
import pandas as pd

# %%
# 세종대학교_크롤링_불가
# 문제점_발견
# 하이퍼링트 내 교과 목표 및 개요 텍스트 출력 불가


from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
import time
import pandas as pd


driver = webdriver.Chrome("C:\chromedriver.exe")
#  창크기 최대화
driver.maximize_window()

# 홈페이지 접속
driver.get("https://sjpt.sejong.ac.kr/websquare/websquare.html?w2xPath=/sch/ext/SueOpenTimeQ.xml&extLocale=ko")
time.sleep(3)

for i in range(2, 3):

    driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_button"]').click()
    driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_itemTable_main"]/tbody/tr['+str(i)+']').click()
    driver.find_element(By.XPATH, '//*[@id="mf_anchor3"]').click()
    time.sleep(1)

    try:
        # 교과목개요 클릭
        # driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_0_10"]/nobr/a').click
        pyautogui.moveTo(1196, 315)
        time.sleep(0.5)
        pyautogui.click()
        time.sleep(1)
        # gaeyo = driver.find_element(By.XPATH, '//*[@id="oziviw_1"]/svg/g/g[16]/rect').text
        gaeyo = driver.find_element(By.XPATH, "(//*[local-name()='g']//*[local-name()='svg']//*[local-name()='g']//*[local-name()='g'])[17]")
        # 교과목개요 텍스트 출력
        print(gaeyo)
        # 하이퍼링크 창 닫기
        pyautogui.moveTo(1488, 168)
        time.sleep(0.5)
        pyautogui.click()


    except:
        # driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_0_10"]/nobr/a').click
        pyautogui.moveTo(1196, 315)
        time.sleep(0.5)
        pyautogui.click()
        print('교과목 개요 텍스트 출력이 안됨')
        pyautogui.moveTo(1488, 168)
        time.sleep(0.5)
        pyautogui.click()
        

    try:
        # 수업계획서 클릭
        # driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_0_11"]/nobr/a').click
        pyautogui.moveTo(1275, 317)
        time.sleep(0.5)
        pyautogui.click()
        time.sleep(1)
        # mokpyo = driver.find_element(By.XPATH, '//*[@id="oziviw_1"]/svg/g[1]/g[49]/rect').text

        mokpyo = driver.find_element(By.XPATH, "(//*[local-name()='g']//*[local-name()='svg']//*[local-name()='g']//*[local-name()='g'])[50]")
        print(mokpyo)
        pyautogui.moveTo(1488, 168)
        time.sleep(0.5)
        pyautogui.click()


    except:
        # driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_0_11"]/nobr/a').click
        pyautogui.moveTo(1275, 317)
        time.sleep(0.5)
        pyautogui.click()
        time.sleep(1)
        print('교과목표 텍스트 출력이 안됨')
        pyautogui.moveTo(1488, 168)
        time.sleep(0.5)
        pyautogui.click()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_22264\1608199491.py:18: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:\chromedriver.exe")
# 교과목 개요 텍스트 출력이 안됨
# 교과목표 텍스트 출력이 안됨

# %% [markdown]
# #### 수업계획서 교과목표 위치
# (//*[local-name()='g']//*[local-name()='svg']//*[local-name()='g']//*[local-name()='g'])[50]
#
# #### 교과목개요 교과목명
# (//*[local-name()='g']//*[local-name()='svg']//*[local-name()='g']//*[local-name()='g'])[8]
#
# #### 교과목개요 교과목개요
# (//*[local-name()='g']//*[local-name()='svg']//*[local-name()='g']//*[local-name()='g'])[17]

# %% [markdown]
# #path, url 주소
# path = "chromedriver.exe"
# url = "https://sjpt.sejong.ac.kr/websquare/websquare.html?w2xPath=/sch/ext/SueOpenTimeQ.xml&extLocale=ko"
#
# driver = webdriver.Chrome(path)
# driver.get(url)
# time.sleep(2)
#
#
# maj_list = []       # 개설학과전공
# num_list = []       # 학수번호
# div_cla_list = []   # 분반
# lec_list = []       # 교과목명
# cla_txt_list = []   # 이수구분
# score_per_list = [] # 학점/이론/실습
# gra_list = []       # 학년
# tar_pro_list = []   # 대상과정
# est_list = []       # 주관학과
# pro_list = []       # 담당교수
# time_list = []      # 요일 및 강의시간
# loc_list = []       # 강의실
# inf_list = []       # 수강대상 및 유의사항
#
# cla_ind_list = []   # 교과목개요
# tar_stu_list = []   # 수강대상
# bef_stu_list = []   # 선수과목
# obj_list = []       # 교과목표
# upd_pla_list = []   # 강의 개선 계획
# intro_list = []     # 교과목 개요
#
#
# #### 화면(폰트 사이즈)  Zoom out 80%
# #driver.execute_script("document.body.style.zoom='50%'")
#
# ####  창크기 최대화
# driver.maximize_window()
#
# i_total_num_list = []
# prev_height = driver.execute_script("return document. body.scrollHeight")
#
#
# for i in range(6, 7):
#     driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_button"]').click()
#     driver.find_element(By.XPATH, '//*//*[@id="mf_cbb_deptCd_itemTable_'+str(i)+'"]').click()
#     driver.find_element(By.XPATH, '//*[@id="mf_anchor3"]').click()
#     time.sleep(5)
#
#     total_num = driver.find_element(By.XPATH, '//*[@id="mf_stc_grd_mainCnt"]').text
#     i_total_num = int(total_num) # 검색 총 건수 정수화
#     i_total_num_list.append(i_total_num)
#
#
#
#     for j in range(0, i_total_num):
#
#         maj_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_0"]').text
#         maj_list.append(maj_txt)            # 개설학과전공
#
#         num_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_1"]').text
#         num_list.append(num_txt)            # 학수번호
#
#         div_cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_2"]').text
#         div_cla_list.append(div_cla_txt)     # 분반
#
#         lec_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_3"]').text
#         lec_list.append(lec_txt)            # 교과목명
#
#         cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_5"]').text
#         cla_txt_list.append(cla_txt)        # 이수구분
#
#         score_per_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_7"]').text
#         score_per_list.append(score_per_txt) # 학점/이론/실습
#
#         gra_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_8"]').text
#         gra_list.append(gra_txt)             # 학년(학기)
#
#         tar_pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_9"]').text   # 대상과정
#         tar_pro_list.append(tar_pro_txt)     # 대상과정
#
#         est_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_12"]').text      # 주관학과
#         est_list.append(est_txt)             # 주관학과
#
#         pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_13"]').text      # 담당교수
#         pro_list.append(pro_txt)             # 담당교수
#
#         time_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_14"]').text     # 요일 및 강의시간
#         time_list.append(time_txt)           # 요일 및 강의시간
#
#         loc_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_15"]').text      # 강의실
#         loc_list.append(loc_txt)             # 강의실
#
#         driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_10"]').click()
#         driver.switch_to.frame("targetOzReport")
#         intro_txt = driver.find_element(By.XPATH, '//*[@id="oziviw_1"]/svg/g/g[16]/rect"]').text      # 교과목개요
#         intro_list.append(intro_txt)             # 교과목개요
#         driver.find_element(By.XPATH, '//*[@id="mf_comReport160659798_close"').click()
#
#
#
#
#
#
# df_SG = pd.DataFrame({'개설학과전공':maj_list,
#                     '학수번호':num_list,
#                     '교과목명':lec_list,
#                     '이수구분':cla_txt_list,
#                     '분반':div_cla_list,
#                     '학점/이론/실습':score_per_list,
#                     '학년':gra_list,
#                     '대상과정':tar_pro_list,
#                     '주관학과': est_list,
#                     '요일및강의시간' : time_list,
#                     '강의실':loc_list,
#                     '담당교수':pro_list,
#                     '교과목개요': intro_list})
#
#
#
# df_SG

# %%
#path, url 주소
path = "chromedriver.exe"
url = "https://sjpt.sejong.ac.kr/websquare/websquare.html?w2xPath=/sch/ext/SueOpenTimeQ.xml&extLocale=ko"

driver = webdriver.Chrome(path)
driver.get(url)
time.sleep(2)


maj_list = []       # 개설학과전공
num_list = []       # 학수번호
div_cla_list = []   # 분반
lec_list = []       # 교과목명
cla_txt_list = []   # 이수구분
score_per_list = [] # 학점/이론/실습
gra_list = []       # 학년
tar_pro_list = []   # 대상과정
est_list = []       # 주관학과
pro_list = []       # 담당교수
time_list = []      # 요일 및 강의시간
loc_list = []       # 강의실
inf_list = []       # 수강대상 및 유의사항

cla_ind_list = []   # 교과목개요
tar_stu_list = []   # 수강대상
bef_stu_list = []   # 선수과목
obj_list = []       # 교과목표
upd_pla_list = []   # 강의 개선 계획
intro_list = []     # 교과목 개요


# 화면(폰트 사이즈)  Zoom out 80%
#driver.execute_script("document.body.style.zoom='50%'")

#  창크기 최대화
driver.maximize_window()

i_total_num_list = []
prev_height = driver.execute_script("return document. body.scrollHeight")


for i in range(1, 2):
    driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_button"]').click()
    driver.find_element(By.XPATH, '//*//*[@id="mf_cbb_deptCd_itemTable_'+str(i)+'"]').click()
    driver.find_element(By.XPATH, '//*[@id="mf_anchor3"]').click()
    time.sleep(5)

    total_num = driver.find_element(By.XPATH, '//*[@id="mf_stc_grd_mainCnt"]').text
    i_total_num = int(total_num) # 검색 총 건수 정수화
    i_total_num_list.append(i_total_num)
        
driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_10"]').click()
time.sleep(5)
driver.switch_to.frame('##')
intro_txt = driver.find_element(By.XPATH, '//*[@id="oziviw_1"]/svg/g/g[16]/rect"]').text      # 교과목개요
intro_list.append(intro_txt)             # 교과목개요
driver.find_element(By.XPATH, '//*[@id="mf_comReport160659798_close"').click()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_138988\624939646.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_138988\624939646.py in <module>
#      54         time.sleep(5)
#      55         driver.switch_to.default_content()
# ---> 56         intro_txt = driver.find_element(By.XPATH, '//*[@id="oziviw_1"]/svg/g/g[16]/rect"]').text      # 교과목개요
#      57         intro_list.append(intro_txt)             # 교과목개요
#      58         driver.find_element(By.XPATH, '//*[@id="mf_comReport160659798_close"').click()
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     828             value = f'[name="{value}"]'
# ...

# %% [markdown]
# > ### 세종대학교 강의시간표/수업계획서 크롤링 코드

# %%
#path, url 주소
path = "chromedriver.exe"
url = "https://sjpt.sejong.ac.kr/websquare/websquare.html?w2xPath=/sch/ext/SueOpenTimeQ.xml&extLocale=ko"

driver = webdriver.Chrome(path)
driver.get(url)
time.sleep(3)


maj_list = []       # 개설학과전공
num_list = []       # 학수번호
div_cla_list = []   # 분반
lec_list = []       # 교과목명
cla_txt_list = []   # 이수구분
score_per_list = [] # 학점/이론/실습
gra_list = []       # 학년
tar_pro_list = []   # 대상과정
est_list = []       # 주관학과
pro_list = []       # 담당교수
time_list = []      # 요일 및 강의시간
loc_list = []       # 강의실
inf_list = []       # 수강대상 및 유의사항

cla_ind_list = []   # 교과목개요
tar_stu_list = []   # 수강대상
bef_stu_list = []   # 선수과목
obj_list = []       # 교과목표
upd_pla_list = []   # 강의 개선 계획


#  창크기 최대화
driver.maximize_window()

# 화면(폰트 사이즈)  Zoom out 80%
#driver.execute_script("document.body.style.zoom='80%'")


i_total_num_list = []


for i in range(8, 9):
    driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_button"]').send_keys(Keys.ENTER)
    driver.find_element(By.XPATH, '//*//*[@id="mf_cbb_deptCd_itemTable_'+str(i)+'"]').send_keys(Keys.ENTER)
    driver.find_element(By.XPATH, '//*[@id="mf_anchor3"]').send_keys(Keys.ENTER)
    time.sleep(3)

    total_num = driver.find_element(By.XPATH, '//*[@id="mf_stc_grd_mainCnt"]').text
    i_total_num = int(total_num) # 검색 총 건수 정수화
    i_total_num_list.append(i_total_num)



    for j in range(0, i_total_num):
        maj_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_0"]').text
        num_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_1"]').text
        div_cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_2"]').text
        lec_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_3"]').text
        cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_5"]').text
        score_per_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_7"]').text
        gra_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_8"]').text
        tar_pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_9"]').text   # 대상과정
        est_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_12"]').text      # 주관학과
        pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_13"]').text      # 담당교수
        time_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_14"]').text     # 요일 및 강의시간
        loc_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_15"]').text      # 강의실
        inf_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_19"]').text
        

        maj_list.append(maj_txt)            # 개설학과전공
        num_list.append(num_txt)            # 학수번호
        lec_list.append(lec_txt)            # 교과목명
        cla_txt_list.append(cla_txt)        # 이수구분
        div_cla_list.append(div_cla_txt)     # 분반
        score_per_list.append(score_per_txt) # 학점/이론/실습
        gra_list.append(gra_txt)             # 학년
        tar_pro_list.append(tar_pro_txt)     # 대상과정
        est_list.append(est_txt)             # 주관학과
        time_list.append(time_txt)           # 요일 및 강의시간
        loc_list.append(loc_txt)             # 강의실
        pro_list.append(pro_txt)             # 담당교수
        inf_list.append(inf_txt)             # 수강대상 및 유의사항
        time.sleep(3)




df_SG = pd.DataFrame({'개설학과전공':maj_list,
                    '학수번호':num_list,
                    '교과목명':lec_list,
                    '이수구분':cla_txt_list,
                    '분반':div_cla_list,
                    '학점/이론/실습':score_per_list,
                    '학년':gra_list,
                    '대상과정':tar_pro_list,
                    '주관학과': est_list,
                    '요일및강의시간' : time_list,
                    '강의실':loc_list,
                    '담당교수':pro_list,
                    '수강대상 및 유의사항':inf_list})


        
df_SG
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_96472\77391251.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_96472\77391251.py in <module>
#      40
#      41 for i in range(8, 9):
# ---> 42     driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_button"]').send_keys(Keys.ENTER)
#      43     driver.find_element(By.XPATH, '//*//*[@id="mf_cbb_deptCd_itemTable_'+str(i)+'"]').send_keys(Keys.ENTER)
#      44     driver.find_element(By.XPATH, '//*[@id="mf_anchor3"]').send_keys(Keys.ENTER)
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py in send_keys(self, *value)
#     228                 value = "\n".join(remote_files)
#     229
# ...

# %%
#path, url 주소
path = "/chromedriver/chromedriver.exe"
url = "https://sjpt.sejong.ac.kr/websquare/websquare.html?w2xPath=/sch/ext/SueOpenTimeQ.xml&extLocale=ko"

driver = webdriver.Chrome(path)
driver.get(url)
time.sleep(3)


maj_list = []       # 개설학과전공
num_list = []       # 학수번호
div_cla_list = []   # 분반
lec_list = []       # 교과목명
cla_txt_list = []   # 이수구분
score_per_list = [] # 학점/이론/실습
gra_list = []       # 학년
tar_pro_list = []   # 대상과정
est_list = []       # 주관학과
pro_list = []       # 담당교수
time_list = []      # 요일 및 강의시간
loc_list = []       # 강의실
inf_list = []       # 수강대상 및 유의사항

cla_ind_list = []   # 교과목개요
tar_stu_list = []   # 수강대상
bef_stu_list = []   # 선수과목
obj_list = []       # 교과목표
upd_pla_list = []   # 강의 개선 계획

#  창크기 최대화
driver.maximize_window()


for i in range(2, 3):

    driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_button"]').click()
    driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_itemTable_main"]/tbody/tr['+str(i)+']').click()
    driver.find_element(By.XPATH, '//*[@id="mf_anchor3"]').click()
    driver.implicitly_wait(1)

    # 검색 총 건수
    total_num = driver.find_element(By.XPATH, '//*[@id="mf_stc_grd_mainCnt"]').text
    i_total_num = int(total_num) # 검색 총 건수 정수화


    try:
        for j in range(0, i_total_num):
            maj_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_0"]').text
            num_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_1"]').text
            div_cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_2"]').text
            lec_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_3"]').text
            cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_5"]').text
            score_per_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_7"]').text
            gra_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_8"]').text
            tar_pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_9"]').text   # 대상과정
            est_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_12"]').text      # 주관학과
            pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_13"]').text      # 담당교수
            time_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_14"]').text     # 요일 및 강의시간
            loc_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_15"]').text      # 강의실
            inf_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_19"]').text
            

            maj_list.append(maj_txt)            # 개설학과전공
            num_list.append(num_txt)            # 학수번호
            lec_list.append(lec_txt)            # 교과목명
            cla_txt_list.append(cla_txt)        # 이수구분
            div_cla_list.append(div_cla_txt)     # 분반
            score_per_list.append(score_per_txt) # 학점/이론/실습
            gra_list.append(gra_txt)             # 학년
            tar_pro_list.append(tar_pro_txt)     # 대상과정
            est_list.append(est_txt)             # 주관학과
            time_list.append(time_txt)           # 요일 및 강의시간
            loc_list.append(loc_txt)             # 강의실
            pro_list.append(pro_txt)             # 담당교수
            inf_list.append(inf_txt)             # 수강대상 및 유의사항
            time.sleep(3)
    except:
        for j in range(0, i_total_num):
            maj_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_0"]').text
            num_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_1"]').text
            div_cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_2"]').text
            lec_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_3"]').text
            cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_5"]').text
            score_per_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_7"]').text
            gra_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_8"]').text
            tar_pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_9"]').text   # 대상과정
            est_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_12"]').text      # 주관학과
            pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_13"]').text      # 담당교수
            time_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_14"]').text     # 요일 및 강의시간
            loc_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_15"]').text      # 강의실
            inf_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(j)+'_19"]').text
            

            maj_list.append('')            # 개설학과전공
            num_list.append('')            # 학수번호
            lec_list.append('')            # 교과목명
            cla_txt_list.append('')        # 이수구분
            div_cla_list.append('')     # 분반
            score_per_list.append('') # 학점/이론/실습
            gra_list.append('')             # 학년
            tar_pro_list.append('')     # 대상과정
            est_list.append('')             # 주관학과
            time_list.append('')           # 요일 및 강의시간
            loc_list.append('')             # 강의실
            pro_list.append('')             # 담당교수
            inf_list.append('')             # 수강대상 및 유의사항
            time.sleep(3)


    




df_SG = pd.DataFrame({'개설학과전공':maj_list, '학수번호':num_list, '교과목명':lec_list, '이수구분':cla_txt_list,
                    '분반':div_cla_list, '학점/이론/실습':score_per_list, '학년':gra_list, '대상과정':tar_pro_list,
                    '주관학과': est_list, '요일및강의시간' : time_list, '강의실':loc_list, '담당교수':pro_list, 
                    '수강대상 및 유의사항':inf_list})


        
df_SG
# Out:
#   File "C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_96472\3597353662.py", line 81
#     df_SG = pd.DataFrame({'개설학과전공':maj_list, '학수번호':num_list, '교과목명':lec_list, '이수구분':cla_txt_list,
#                                                                                                    ^
# IndentationError: unexpected unindent

# %%
## stack_overflow_site_selenium_scroll_left_example_code
# https://stackoverflow.com/questions/62119348/how-to-scroll-horizontally-using-selenium-chromedriver-in-python


#path, url 주소
path = "/chromedriver/chromedriver.exe"
url = "https://www.macrotrends.net/stocks/charts/AAPL/apple/balance-sheet"

driver = webdriver.Chrome(path)
driver.get(url)
time.sleep(3)


horizontal_bar_width = driver.find_element(By.ID, 'jqxScrollOuterWraphorizontalScrollBarjqxgrid').rect['width']
slider = driver.find_element(By.ID,'jqxScrollThumbhorizontalScrollBarjqxgrid')

header_columns = []

# Using iteration as span values won't show went they are hidden
for _ in range(4):
    for el in driver.find_elements(By.CSS_SELECTOR, '#columntablejqxgrid [role="columnheader"] span'):
        if el.text not in header_columns and el.text != '':
            header_columns.append(el.text)
    # Ensure the slider is in view
    slider.location_once_scrolled_into_view
    ActionChains(driver).click_and_hold(slider).move_by_offset(horizontal_bar_width/4, 0).release().perform()

header_columns
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_96472\3148030661.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# ['Annual Data | Millions of US $ except per share data',
#  '2022-09-30',
#  '2021-09-30',
#  '2020-09-30',
#  '2019-09-30',
#  '2018-09-30',
#  '2017-09-30',
#  '2016-09-30',
#  '2015-09-30',
#  '2014-09-30',
#  '2013-09-30',
#  '2012-09-30',
#  '2011-09-30',
#  '2010-09-30',
#  '2009-09-30']

# %% [markdown]
# > ### 변수 list 정의

# %%
maj_list = []       # 개설학과전공
num_list = []       # 학수번호
div_cla_list = []   # 분반
lec_list = []       # 교과목명
cla_txt_list = []   # 이수구분
score_per_list = [] # 학점/이론/실습
gra_list = []       # 학년
tar_pro_list = []   # 대상과정
est_list = []       # 주관학과
pro_list = []       # 담당교수
time_list = []      # 요일 및 강의시간
loc_list = []       # 강의실
inf_list = []       # 수강대상 및 유의사항

cla_ind_list = []   # 교과목개요
tar_stu_list = []   # 수강대상
bef_stu_list = []   # 선수과목
obj_list = []       # 교과목표
upd_pla_list = []   # 강의 개선 계획


# 검색 총 건수
total_num = driver.find_element(By.XPATH, '//*[@id="mf_stc_grd_mainCnt"]').text
i_total_num = int(total_num) # 검색 총 건수 정수화


for i in range(0, i_total_num):
    maj_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_0"]').text
    num_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_1"]').text
    div_cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_2"]').text
    lec_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_3"]').text
    cla_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_5"]').text
    score_per_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_7"]').text
    gra_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_8"]').text
    tar_pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_9"]').text   # 대상과정
    est_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_12"]').text      # 주관학과
    pro_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_13"]').text      # 담당교수
    time_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_14"]').text     # 요일 및 강의시간
    loc_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_15"]').text      # 강의실
    inf_txt = driver.find_element(By.XPATH, '//*[@id="mf_grd_main_cell_'+str(i)+'_19"]').text
    

    maj_list.append(maj_txt)            # 개설학과전공
    num_list.append(num_txt)            # 학수번호
    lec_list.append(lec_txt)            # 교과목명
    cla_txt_list.append(cla_txt)        # 이수구분
    div_cla_list.append(div_cla_txt)     # 분반
    score_per_list.append(score_per_txt) # 학점/이론/실습
    gra_list.append(gra_txt)             # 학년
    tar_pro_list.append(tar_pro_txt)     # 대상과정
    est_list.append(est_txt)             # 주관학과
    time_list.append(time_txt)           # 요일 및 강의시간
    loc_list.append(loc_txt)             # 강의실
    pro_list.append(pro_txt)             # 담당교수
    inf_list.append(inf_txt)             # 수강대상 및 유의사항





pd.DataFrame({'개설학과전공':maj_list,
               '학수번호':num_list,
               '교과목명':lec_list,
               '이수구분':cla_txt_list,
                '분반':div_cla_list,
                '학점/이론/실습':score_per_list,
                '학년':gra_list,
                '대상과정':tar_pro_list,
                '주관학과': est_list,
                '요일및강의시간' : time_list,
                '강의실':loc_list,
                '담당교수':pro_list,
                '수강대상 및 유의사항':inf_list})
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_85852\715340425.py in <module>
#      21
#      22 # 검색 총 건수
# ---> 23 total_num = driver.find_element(By.XPATH, '//*[@id="mf_stc_grd_mainCnt"]').text
#      24 i_total_num = int(total_num) # 검색 총 건수 정수화
#      25
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     828             value = f'[name="{value}"]'
#     829
# --> 830         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     831
#     832     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %% [markdown]
# > ### 혜정님 성신여대 강의계획서 크롤링 코드(1)

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://sugang.sungshin.ac.kr/')
time.sleep(2)

driver.find_element(By.XPATH, '//*[@id="Smenu"]/ul/li[5]/a').click()
driver.implicitly_wait(5)

driver.switch_to.frame('contentsFrm')
dropdown = Select(driver.find_element(By.XPATH, '//*[@id="cmbSbjMngCd"]')) # 과목구분 중 교양 선택
dropdown.select_by_visible_text("교양")
time.sleep(10)

driver.find_element(By.XPATH, '//*[@id="btnSch"]').click() # 조회버튼 클릭
driver.implicitly_wait(3)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_85852\3839675033.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %% [markdown]
# ### 혜정님 성신여대 강의계획서 크롤링 코드(2)

# %%
maj_list = [] # 개설학과전공
num_list = [] # 학수번호
lec_list = [] # 교과목명
cla_num_list = [] # 분반
cla_txt_list = [] # 이수구분
det_list = [] # 영역
sec_list = [] # 교과세부
time_per_list = [] # 학점/이론/실습
tot_list = [] # 수강정원
sha_list = [] # 학점교류
time_list = [] # 시간표
loc_list = [] # 강의실
pro_list = [] # 담당교수
cam_list = [] # 캠퍼스
type_list = [] # 수업유형
inf_list = [] # 수강안내 및 지정내용

max_list = driver.find_element(By.XPATH, '//*[@id="lblGrxMstCnt"]').text
max_list = max_list.replace(' ','')
max_list = max_list.replace('[','')
max_list = max_list.replace(']','')
max_list = int(max_list) + 2

for i in range(2,max_list):
    maj_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[2]').text
    num_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[3]').text
    lec_name = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[4]').text
    cla_num = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[5]').text
    cla_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[6]').text
    det_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[7]').text
    sec_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[8]').text
    time_per = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[9]').text
    tot_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[10]').text
    sha_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[11]').text
    time_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[12]').text
    loc_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[13]').text
    pro_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[14]').text
    cam_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[15]').text
    type_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[16]').text
    inf_txt = driver.find_element(By.XPATH, '//*[@id="grxMst"]/tbody/tr['+str(i)+']/td[17]').text
    
    maj_list.append(maj_txt)
    num_list.append(num_txt)
    lec_list.append(lec_name)
    cla_num_list.append(cla_num)
    cla_txt_list.append(cla_txt)
    det_list.append(det_txt)
    sec_list.append(sec_txt)
    time_per_list.append(time_per)
    tot_list.append(tot_txt)
    sha_list.append(sha_txt)
    time_list.append(time_txt)
    loc_list.append(loc_txt)
    pro_list.append(pro_txt)
    cam_list.append(cam_txt)
    type_list.append(type_txt)
    inf_list.append(inf_txt)
    
    
pd.DataFrame({'개설학과전공':maj_list, '학수번호':num_list, '교과목명':lec_list, '분반':cla_num_list, '이수구분':cla_txt_list, '영역':det_list, '교과세부':sec_list,
              '학점/이론/실습':time_per_list, '수강정원':tot_list, '학점교류':sha_list, '시간표':time_list, '강의실':loc_list, '담당교수':pro_list, '캠퍼스':cam_list,
              '수업유형':type_list, '수강안내 및 지정내용':inf_list})
# Out:
#   개설학과전공      학수번호                 교과목명   분반  이수구분  영역   교과세부     학점/이론/실습  \
# 0   교양학부  SA020100  공통 영어 스피치와 프레젠테이션 Ⅰ  001  공통교양  영어  글로벌역량  3.0/1.5/1.5
#
#   수강정원 학점교류    시간표 강의실 담당교수 캠퍼스 수업유형  \
# 0   30       화/1-3           수정   일반
#
#                                          수강안내 및 지정내용
# 0  2018이후 학번 대상 Effective English Speech 대체과목 201...

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://sjpt.sejong.ac.kr/app/ext/SueOpenTimeQ.jsp")
driver.implicitly_wait(5)


driver.find_element(By.ID, 'mf_wq_uuid_37').text()
#driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_itemTable_2"]').click()
#driver.find_element(By.XPATH, '//*[@id="mf_anchor3"]').click()
#driver.implicitly_wait(5)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_85852\1599958556.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_85852\1599958556.py in <module>
#       4
#       5
# ----> 6 driver.find_element(By.ID, 'mf_wq_uuid_37').text
#       7 #driver.find_element(By.XPATH, '//*[@id="mf_cbb_deptCd_itemTable_2"]').click()
#       8 #driver.find_element(By.XPATH, '//*[@id="mf_anchor3"]').click()
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     828             value = f'[name="{value}"]'
#     829
# --> 830         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
# ...

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium import webdriver
import time
import openpyxl
import pandas as pd
import pyautogui

print('Close Position:',pyautogui.position())
# Close Position: Point(x=1488, y=168)
# 교과목개요 버튼 Position: Point(x=1196, y=315)
# 수업계획서 버튼 Position: Point(x=1275, y=317)
# Out:
# Close Position: Point(x=1488, y=168)
